# %% [markdown]
# # Agregación de datos por categoría

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
gender = ["Male", "Female"]
income = ["Poor", "Middle Class", "Rich"]

# %%
n = 500  #necesitamos 500 datos generados

gender_data = []
income_data = []

#hacemos un bucle
for i in range(0,500):
    gender_data.append(np.random.choice(gender)) #para elegir aleatoriamente un elemento de gender
    income_data.append(np.random.choice(income)) #para elegir aleatoriamente un elemento de income

# %%
gender_data[1:10]
# Out:
# ['Male',
#  'Female',
#  'Male',
#  'Female',
#  'Male',
#  'Female',
#  'Female',
#  'Male',
#  'Female']

# %%
income_data[1:10]
# Out:
# ['Poor',
#  'Rich',
#  'Rich',
#  'Middle Class',
#  'Poor',
#  'Middle Class',
#  'Middle Class',
#  'Poor',
#  'Middle Class']

# %%
#si quiero más:
# para estilizar según distribución de media m y desviación tipica s es N(m,s) -> m + s * Z
# la Z en este curso siempre significa una Normal de media 0 y Std 1 Z -> N(0,1)
height = 160 + 30 * np.random.randn(n)  #la altura suele tener distribución normal
weight = 65 + 25 * np.random.randn(n)  #el peso suele tener distribución normal
age = 30 + 12 * np.random.randn(n)     # suele tener distribución 
income = 18000 + 3500 * np.random.randn(n)

# %%
#genero el dataframe
data = pd.DataFrame(
    {
        "Gender" : gender_data,
        "Economic Status" : income_data,
        "Height" : height,
        "Weight" : weight,
        "Age" : age,
        "Income" : income
    }


)

# %%
data.head()
# Out:
#    Gender Economic Status      Height     Weight        Age        Income
# 0    Male    Middle Class  178.696613  62.515886  31.184664  12361.783820
# 1    Male            Poor  156.606136  76.980095  49.135368  19650.551933
# 2  Female            Rich  159.429548  56.848688  22.339970  20317.528413
# 3    Male            Rich  113.727788  75.909521  30.651248  20180.116220
# 4  Female    Middle Class  167.678243  29.741709  15.791572  15839.784017

# %% [markdown]
# # Agrupación

# %%
#agrupo por genero
grouped_gender = data.groupby("Gender") #crea un objeto con 2 atributos, uno de ellos es el nombre y el grupo

#Estos atributos se pueden acceder con sintaxis a traves de puntos

# %%
grouped_gender.groups
# Out:
# {'Female': [2, 4, 6, 7, 9, 10, 13, 15, 19, 20, 21, 23, 24, 26, 31, 34, 35, 39, 43, 44, 45, 49, 50, 51, 56, 59, 60, 63, 64, 65, 68, 71, 73, 77, 78, 81, 83, 84, 85, 86, 88, 89, 91, 92, 93, 94, 95, 97, 99, 100, 101, 105, 107, 108, 109, 110, 113, 114, 115, 117, 118, 119, 121, 122, 128, 129, 130, 131, 132, 134, 135, 136, 137, 139, 143, 145, 146, 147, 148, 150, 151, 154, 157, 160, 161, 163, 164, 166, 167, 168, 171, 172, 173, 176, 178, 179, 180, 181, 182, 184, ...], 'Male': [0, 1, 3, 5, 8, 11, 12, 14, 16, 17, 18, 22, 25, 27, 28, 29, 30, 32, 33, 36, 37, 38, 40, 41, 42, 46, 47, 48, 52, 53, 54, 55, 57, 58, 61, 62, 66, 67, 69, 70, 72, 74, 75, 76, 79, 80, 82, 87, 90, 96, 98, 102, 103, 104, 106, 111, 112, 116, 120, 123, 124, 125, 126, 127, 133, 138, 140, 141, 142, 144, 149, 152, 153, 155, 156, 158, 159, 162, 165, 169, 170, 174, 175, 177, 183, 186, 189, 190, 191, 195, 196, 200, 201, 203, 204, 206, 207, 208, 209, 210, ...]}

# %%
# hecha la agrupación, puede iterar sobre cada una de las opciones.  ej con un bucle
# util cuando hay muchos grupos y se necesitan operaciones separadas para cada grupo


for names, groups in grouped_gender:
    print(names)
    print(groups)
# Out:
# Female
#      Gender Economic Status      Height      Weight        Age        Income
# 2    Female            Rich  159.429548   56.848688  22.339970  20317.528413
# 4    Female    Middle Class  167.678243   29.741709  15.791572  15839.784017
# 6    Female    Middle Class  170.863634   91.703255  19.700296  22589.149082
# 7    Female    Middle Class  145.766860   55.697443  51.839548  19785.288162
# 9    Female    Middle Class  156.975606   54.713996  19.818613  21889.996782
# ..      ...             ...         ...         ...        ...           ...
# 493  Female            Rich  170.359177   39.846269  24.251894  23733.866802
# 495  Female    Middle Class  160.290449   89.129812  47.643532  14325.099686
# 496  Female            Rich  151.440812   42.912428  28.632907  17623.823244
# 498  Female            Poor  181.786356  123.722582  36.110569  17288.523062
# 499  Female            Poor  197.693931   38.579076  38.073667  19315.360287
#
# [245 rows x 6 columns]
# Male
#     Gender Economic Status      Height      Weight        Age        Income
# 0     Male    Middle Class  178.696613   62.515886  31.184664  12361.783820
# 1     Male            Poor  156.606136   76.980095  49.135368  19650.551933
# 3     Male            Rich  113.727788   75.909521  30.651248  20180.116220
# 5     Male            Poor  136.383384  129.528542  14.364274  13921.145818
# 8     Male            Poor  152.062195   91.982701  21.262440  17504.701833
# ..     ...             ...         ...         ...        ...           ...
# 487   Male            Poor  233.140148   62.076608  31.580899  18936.431597
# 489   Male            Rich  142.289192   79.427326   6.247195  24226.715259
# 490   Male            Rich  125.544904   61.256119  23.791265  21789.385700
# 494   Male    Middle Class  147.742278   51.462341  37.907780  15036.245520
# 497   Male            Rich  145.050683   74.174945  41.497402  19817.383181
#
# [255 rows x 6 columns]

# %%
grouped_gender.get_group("Female")
# Out:
#      Gender Economic Status      Height      Weight        Age        Income
# 2    Female            Rich  159.429548   56.848688  22.339970  20317.528413
# 4    Female    Middle Class  167.678243   29.741709  15.791572  15839.784017
# 6    Female    Middle Class  170.863634   91.703255  19.700296  22589.149082
# 7    Female    Middle Class  145.766860   55.697443  51.839548  19785.288162
# 9    Female    Middle Class  156.975606   54.713996  19.818613  21889.996782
# ..      ...             ...         ...         ...        ...           ...
# 493  Female            Rich  170.359177   39.846269  24.251894  23733.866802
# 495  Female    Middle Class  160.290449   89.129812  47.643532  14325.099686
# 496  Female            Rich  151.440812   42.912428  28.632907  17623.823244
# 498  Female            Poor  181.786356  123.722582  36.110569  17288.523062
# 499  Female            Poor  197.693931   38.579076  38.073667  19315.360287
#
# [245 rows x 6 columns]

# %%
#genero otro grupo
grouped_Economic_Status = data.groupby("Economic Status")

# %%
grouped_Economic_Status.groups
# Out:
# {'Middle Class': [0, 4, 6, 7, 9, 10, 11, 12, 15, 23, 30, 33, 34, 36, 40, 43, 44, 46, 49, 52, 55, 57, 59, 63, 65, 66, 69, 71, 72, 76, 78, 88, 91, 92, 93, 94, 96, 99, 101, 109, 121, 124, 125, 128, 131, 133, 135, 140, 142, 143, 148, 158, 159, 160, 161, 163, 166, 168, 169, 170, 181, 184, 186, 187, 190, 195, 198, 212, 218, 219, 221, 229, 232, 234, 236, 238, 239, 242, 243, 246, 249, 250, 251, 253, 254, 255, 256, 261, 262, 265, 266, 270, 271, 272, 275, 277, 278, 281, 283, 287, ...], 'Poor': [1, 5, 8, 17, 18, 19, 21, 24, 25, 31, 32, 35, 37, 38, 41, 42, 47, 48, 50, 51, 53, 56, 61, 62, 64, 75, 77, 83, 84, 86, 89, 90, 97, 100, 102, 103, 104, 106, 107, 108, 110, 113, 117, 118, 120, 122, 126, 127, 129, 130, 134, 137, 139, 141, 144, 145, 147, 149, 150, 151, 153, 154, 156, 162, 164, 167, 171, 177, 178, 179, 180, 182, 185, 188, 189, 194, 196, 197, 200, 201, 202, 205, 207, 210, 213, 217, 222, 223, 224, 225, 233, 235, 237, 244, 279, 282, 290, 291, 294, 297, ...], 'Rich': [2, 3, 13, 14, 16, 20, 22, 26, 27, 28, 29, 39, 45, 54, 58, 60, 67, 68, 70, 73, 74, 79, 80, 81, 82, 85, 87, 95, 98, 105, 111, 112, 114, 115, 116, 119, 123, 132, 136, 138, 146, 152, 155, 157, 165, 172, 173, 174, 175, 176, 183, 191, 192, 193, 199, 203, 204, 206, 208, 209, 211, 214, 215, 216, 220, 226, 227, 228, 230, 231, 240, 241, 245, 247, 248, 252, 257, 258, 259, 260, 263, 264, 267, 268, 269, 273, 274, 276, 280, 284, 285, 286, 288, 293, 295, 301, 304, 306, 308, 313, ...]}

# %%
grouped_Economic_Status.get_group("Rich")
# Out:
#      Gender Economic Status      Height     Weight        Age        Income
# 2    Female            Rich  159.429548  56.848688  22.339970  20317.528413
# 3      Male            Rich  113.727788  75.909521  30.651248  20180.116220
# 13   Female            Rich  152.216986  38.818521  23.089335  15489.467484
# 14     Male            Rich  173.511349  68.007094  36.157695  21970.547326
# 16     Male            Rich  131.768600  21.057237  44.192602  21355.625119
# ..      ...             ...         ...        ...        ...           ...
# 489    Male            Rich  142.289192  79.427326   6.247195  24226.715259
# 490    Male            Rich  125.544904  61.256119  23.791265  21789.385700
# 493  Female            Rich  170.359177  39.846269  24.251894  23733.866802
# 496  Female            Rich  151.440812  42.912428  28.632907  17623.823244
# 497    Male            Rich  145.050683  74.174945  41.497402  19817.383181
#
# [151 rows x 6 columns]

# %%
#para varios
double_group = data.groupby(["Gender", "Economic Status"])

# %%
len(double_group)
# Out:
# 6

# %%
for names, groups in double_group:
    print(names)
    print(groups)
# Out:
# ('Female', 'Middle Class')
#      Gender Economic Status      Height     Weight        Age        Income
# 4    Female    Middle Class  167.678243  29.741709  15.791572  15839.784017
# 6    Female    Middle Class  170.863634  91.703255  19.700296  22589.149082
# 7    Female    Middle Class  145.766860  55.697443  51.839548  19785.288162
# 9    Female    Middle Class  156.975606  54.713996  19.818613  21889.996782
#        Poor             162.697536  181.816134  210.273111   88.0  65.185828
#        Rich             158.614706  174.477955  248.170697   67.0  63.499527
# Male   Middle Class     158.487087  176.258441  232.457143   94.0  60.488719
#        Poor             167.827763  183.109795  244.502271   77.0  64.864090
#        Rich             157.676384  175.306849  242.088654   84.0  62.306512
#
#                         ...        Age            Income                \
#                         ...        75%        max  count          mean
# Gender Economic Status  ...
# Female Middle Class     ...  37.947654  64.964755   90.0  17988.231860
#        Poor             ...  38.046138  65.580594   88.0  17890.872765
#        Rich             ...  39.499625  73.486414   67.0  17544.679132
# Male   Middle Class     ...  38.288339  60.492514   94.0  18866.114458
#        Poor             ...  39.350901  53.130260   77.0  18108.190527
#        Rich             ...  37.965915  60.172049   84.0  17950.701126
#
#                                                                                \
#                                 std           min           25%           50%
# Gender Economic Status
# Female Middle Class     3726.226023  10482.876120  15181.620871  17672.236993
#        Poor             3647.940465  10436.321042  15034.161474  18366.158596
#        Rich             3811.600712   8853.214631  14912.061527  17741.866401
# Male   Middle Class     3901.706726   9210.246423  15897.307353  19167.250373
#        Poor             3821.986889   9913.164692  15328.540554  17871.535287
#        Rich             3687.822865   9632.678306  15723.681872  18203.128824
#
#
#                                  75%           max
# Gender Economic Status
# Female Middle Class     20248.249324  28073.247702
#        Poor             19740.748037  25949.453615
#        Rich             20007.882642  24744.781514
# Male   Middle Class     21693.417493  27526.456139
#        Poor             19990.796115  28502.128901
#        Rich             21117.066693  24434.490577
#
# [6 rows x 32 columns]

# %%
#los objetos groupby se comportan como cualquier dataframe. asi que podemos seleccionar una de esas columnas para realizar cualquier operación
grouped_income = double_group["Income"] 
#para poder ver primero una de las variables y leerla mejor.

# %%
grouped_income.describe()
# Out:
#                         count          mean          std           min  \
# Gender Economic Status
# Female Middle Class      90.0  17988.231860  3726.226023  10482.876120
#        Poor              88.0  17890.872765  3647.940465  10436.321042
#        Rich              67.0  17544.679132  3811.600712   8853.214631
# Male   Middle Class      94.0  18866.114458  3901.706726   9210.246423
#        Poor              77.0  18108.190527  3821.986889   9913.164692
#        Rich              84.0  17950.701126  3687.822865   9632.678306
#
#                                  25%           50%           75%           max
# Gender Economic Status
# Female Middle Class     15181.620871  17672.236993  20248.249324  28073.247702
#        Poor             15034.161474  18366.158596  19740.748037  25949.453615
#        Rich             14912.061527  17741.866401  20007.882642  24744.781514
# Male   Middle Class     15897.307353  19167.250373  21693.417493  27526.456139
#        Poor             15328.540554  17871.535287  19990.796115  28502.128901
#        Rich             15723.681872  18203.128824  21117.066693  24434.490577

# %%
#el metodo aggregate (groupby modificado) sirve para calcular conjuntamente los valores que nos interesen (suma de ingresos, media de edades, etc)

# %%
double_group.aggregate(
    {
        "Income": np.sum,
        "Age": np.mean,
        "Height": np.std
    }

)
# Out:
#                               Income        Age     Height
# Gender Economic Status
# Female Middle Class     1.618941e+06  30.737034  27.941401
#        Poor             1.574397e+06  30.135473  31.186193
#        Rich             1.175494e+06  32.502534  27.991560
# Male   Middle Class     1.773415e+06  31.757878  29.629675
#        Poor             1.394331e+06  30.161857  29.794864
#        Rich             1.507859e+06  29.219979  31.689243

# %%
#el máximo exponente de este tipo de agregados es la función lambda
#para definir un tipo de cálculo específico en python
#ej. en lugar de querer el promedio de la edad, queremos la tipificación osea...
#la media de la edad dividido por la desviación típica
double_group.aggregate(
    {
        "Age": np.mean,
        "Height": lambda h:np.mean(h)/np.std(h)  #lo usual es llamarle x pero se puede como quiera, ej h
        # lambda es una función que se pasa como parámetro de la función aggregate, donde cualquier altura h se divide en la desviación std
    }

)
# Out:
#                               Age    Height
# Gender Economic Status
# Female Middle Class     30.737034  5.867418
#        Poor             30.135473  5.119834
#        Rich             32.502534  5.752613
# Male   Middle Class     31.757878  5.382986
#        Poor             30.161857  5.594325
#        Rich             29.219979  5.073451

# %%
#se pueden aplicar las funciones a todas las columnas
double_group.aggregate([np.sum, np.mean, np.std])
# Out:
#                               Height                              Weight  \
#                                  sum        mean        std          sum
# Gender Economic Status
# Female Middle Class     14672.748680  163.030541  27.941401  5791.038774
#        Poor             13970.732494  158.758324  31.186193  5736.352862
#        Rich             10707.834247  159.818422  27.991560  4254.468326
# Male   Middle Class     14912.673758  158.645466  29.629675  5685.939629
#        Poor             12750.912898  165.596271  29.794864  4994.534963
#        Rich             13424.373730  159.813973  31.689243  5233.746999
#
#                                                       Age             \
#                              mean        std          sum       mean
# Gender Economic Status
# Female Middle Class     64.344875  22.116412  2766.333024  30.737034
#        Poor             65.185828  21.330616  2651.921595  30.135473
#        Rich             63.499527  27.807587  2177.669797  32.502534
# Male   Middle Class     60.488719  26.917456  2985.240551  31.757878
#        Poor             64.864090  25.017619  2322.463008  30.161857
#        Rich             62.306512  22.361017  2454.478218  29.219979
#
#                                          Income
#                               std           sum          mean          std
# Gender Economic Status
# Female Middle Class     12.329026  1.618941e+06  17988.231860  3726.226023
#        Poor             12.463028  1.574397e+06  17890.872765  3647.940465
#        Rich             12.391435  1.175494e+06  17544.679132  3811.600712
# Male   Middle Class     11.384935  1.773415e+06  18866.114458  3901.706726
#        Poor             11.957068  1.394331e+06  18108.190527  3821.986889
#        Rich             12.550843  1.507859e+06  17950.701126  3687.822865

# %%
#para agregar con una lambbda, para aplicar funciones de transformación según haga falta
double_group.aggregate([lambda x: np.mean(x) / np.std(x)])
# Out:
#                           Height    Weight       Age    Income
#                         <lambda>  <lambda>  <lambda>  <lambda>
# Gender Economic Status
# Female Middle Class     5.867418  2.925671  2.507029  4.854511
#        Poor             5.119834  3.073488  2.431846  4.932482
#        Rich             5.752613  2.300767  2.642780  4.637709
# Male   Middle Class     5.382986  2.259242  2.804422  4.861276
#        Poor             5.594325  2.609738  2.539054  4.768968
#        Rich             5.073451  2.803125  2.342112  4.896795

# %% [markdown]
# ## Filtrado de datos

# %%
double_group.sum()
# Out:
#                               Height       Weight          Age        Income
# Gender Economic Status
# Female Middle Class     14672.748680  5791.038774  2766.333024  1.618941e+06
#        Poor             13970.732494  5736.352862  2651.921595  1.574397e+06
#        Rich             10707.834247  4254.468326  2177.669797  1.175494e+06
# Male   Middle Class     14912.673758  5685.939629  2985.240551  1.773415e+06
#        Poor             12750.912898  4994.534963  2322.463008  1.394331e+06
#        Rich             13424.373730  5233.746999  2454.478218  1.507859e+06

# %%
#aplico funcion filter y dentro una lambda
double_group["Age"].filter(lambda x: x.sum()>2500)  
#genera los elementos que pertenecen a un grupo cuya suma se mayor a 2500
# Out:
# 0      31.184664
# 4      15.791572
# 6      19.700296
# 7      51.839548
# 9      19.818613
#          ...
# 492    21.226327
# 494    37.907780
# 495    47.643532
# 498    36.110569
# 499    38.073667
# Name: Age, Length: 272, dtype: float64

# %%
#hacer una transformacion matematica a los elementos de una categoria numerica
#ej calcular la tipificación de los valores de una columna en concreto (Zscore)
zscore = lambda x : (x - x.mean())/x.std() #a x le resto el promedio de todas las x y divido por la std de todas las x

# %%
#el resultado es un dataframe donte tiene todos los datos normalizados o estandarizados
#para dibujar un plot después le colocamos nombre z_group

z_group = double_group.transform(zscore)

# %%
plt.hist(z_group["Age"])
# Out:
# (array([ 11.,  26.,  61., 117., 110.,  88.,  52.,  28.,   4.,   3.]),
#  array([-2.57919425, -1.99053122, -1.40186818, -0.81320515, -0.22454212,
#          0.36412092,  0.95278395,  1.54144698,  2.13011001,  2.71877305,
#          3.30743608]),
#  <BarContainer object of 10 artists>)

# %%
#el secreto es el uso de la función transform que es útil en casos como cuando faltan datos.
fill_na_mean = lambda x : x.fillna(x.mean())

# %%
double_group.transform(fill_na_mean)
# Out:
#          Height      Weight        Age        Income
# 0    178.696613   62.515886  31.184664  12361.783820
# 1    156.606136   76.980095  49.135368  19650.551933
# 2    159.429548   56.848688  22.339970  20317.528413
# 3    113.727788   75.909521  30.651248  20180.116220
# 4    167.678243   29.741709  15.791572  15839.784017
# ..          ...         ...        ...           ...
# 495  160.290449   89.129812  47.643532  14325.099686
# 496  151.440812   42.912428  28.632907  17623.823244
# 497  145.050683   74.174945  41.497402  19817.383181
# 498  181.786356  123.722582  36.110569  17288.523062
# 499  197.693931   38.579076  38.073667  19315.360287
#
# [500 rows x 4 columns]

# %% [markdown]
# ## Operaciones diversas muy útiles

# %%
#Ej seleciconar la fila nsima de un groupby
#
double_group.head(1) #devuelve el primero de los objetos de cada uno de los grupos
# Out:
#     Gender Economic Status      Height      Weight        Age        Income
# 0     Male    Middle Class  178.696613   62.515886  31.184664  12361.783820
# 1     Male            Poor  156.606136   76.980095  49.135368  19650.551933
# 2   Female            Rich  159.429548   56.848688  22.339970  20317.528413
# 3     Male            Rich  113.727788   75.909521  30.651248  20180.116220
# 4   Female    Middle Class  167.678243   29.741709  15.791572  15839.784017
# 19  Female            Poor  176.713949  107.762176  35.682936  16842.929987

# %%
double_group.tail(1)
# Out:
#      Gender Economic Status      Height     Weight        Age        Income
# 487    Male            Poor  233.140148  62.076608  31.580899  18936.431597
# 494    Male    Middle Class  147.742278  51.462341  37.907780  15036.245520
# 495  Female    Middle Class  160.290449  89.129812  47.643532  14325.099686
# 496  Female            Rich  151.440812  42.912428  28.632907  17623.823244
# 497    Male            Rich  145.050683  74.174945  41.497402  19817.383181
# 499  Female            Poor  197.693931  38.579076  38.073667  19315.360287

# %%
double_group.nth(32) #elemento trigesimo segundo
# Out:
#                             Height      Weight        Age        Income
# Gender Economic Status
# Female Middle Class     174.789874   85.746236  49.497015  17880.736223
#        Poor             185.609938   57.136955  32.377470  20301.698521
#        Rich             123.771181  120.204101  29.250152  15537.968504
# Male   Middle Class     130.475166   34.632862  22.979781  17408.547379
#        Poor             185.176857  121.220748  33.914430  17018.724853
#        Rich             159.337237   54.178054  28.246622  19194.610672

# %%
double_group.nth(82) #en algunos grupos no hay dato 82, entonces devuelve los que hay
# Out:
#                             Height     Weight        Age        Income
# Gender Economic Status
# Female Middle Class     144.346118  64.292174  27.747969  21713.559987
#        Poor             168.140148  73.252586  39.358382  23432.608926
# Male   Middle Class     148.052858  60.703884  36.113351  21752.334781
#        Rich             125.544904  61.256119  23.791265  21789.385700

# %%
#Es común ordenar la info del dataframe para ordenar según las columnas mas relevantes antes de crear el objeto agrupado del dataframe original
#Supongamos que queremos ver los más jóvenes, antes de crear el groupby

data_sorted = data.sort_values(["Age", "Income"])

# %%
data_sorted.head(10)
# Out:
#      Gender Economic Status      Height     Weight       Age        Income
# 480  Female            Poor  117.732876  56.704725 -1.315565  15055.065166
# 358  Female    Middle Class  182.814721  21.637363 -1.061920  23444.454318
# 357  Female            Poor  188.837760  50.422815 -1.053102  22130.332594
# 264    Male            Rich  131.763710  95.700937  1.487564  18701.626752
# 210    Male            Poor  190.826603  58.789236  2.434025  13149.580190
# 165    Male            Rich  153.822144  82.584774  2.963027  16887.029628
# 477    Male            Rich  132.426418  84.440241  3.854414  16906.769963
# 102    Male            Poor  139.135893  62.291989  4.101323  19652.703197
# 364    Male            Rich  156.359440  60.814111  5.529895  21746.408896
# 489    Male            Rich  142.289192  79.427326  6.247195  24226.715259

# %%
#ahora que están ordenado, hacemos el groupby
age_grouped = data_sorted.groupby("Gender")

# %%
age_grouped.head()
# Out:
#      Gender Economic Status      Height     Weight       Age        Income
# 480  Female            Poor  117.732876  56.704725 -1.315565  15055.065166
# 358  Female    Middle Class  182.814721  21.637363 -1.061920  23444.454318
# 357  Female            Poor  188.837760  50.422815 -1.053102  22130.332594
# 264    Male            Rich  131.763710  95.700937  1.487564  18701.626752
# 210    Male            Poor  190.826603  58.789236  2.434025  13149.580190
# 165    Male            Rich  153.822144  82.584774  2.963027  16887.029628
# 477    Male            Rich  132.426418  84.440241  3.854414  16906.769963
# 102    Male            Poor  139.135893  62.291989  4.101323  19652.703197
# 100  Female            Poor  133.752132  30.855787  6.496133  16271.458216
# 431  Female            Rich  129.257788   7.355919  8.642447  16261.741225

# %%
age_grouped.tail(1)
# Out:
#      Gender Economic Status      Height     Weight        Age        Income
# 314    Male    Middle Class  174.199102  64.534099  60.492514  17373.006940
# 348  Female            Rich  160.402724  81.139144  73.486414  18272.372323
